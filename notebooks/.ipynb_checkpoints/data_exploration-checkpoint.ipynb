# %% [markdown]
# Import all the needed libraries and load the datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

try:
    gmDevData = pd.read_csv('../data/assignment1_dev_set.csv')
    gmValData = pd.read_csv('../data/assignment1_val_set.csv')
except FileNotFoundError as e:
    print(f"Error: {e}")
    exit()

# %% [markdown]
# Then we have a basic look into the start and the beggining of both files just to know what we are dealing with

# %%
print("a")
display(gmDevData.head())
print("b")
display(gmDevData.tail())

print("\n\n\n")
print("c")
gmValData.head()
print("d")
gmValData.tail()
# Out:
# a
#    Unnamed: 0   Project ID Experiment type     Sex  Host age    BMI  \
# 0           0   PRJEB11419    Metagenomics    Male      53.0  19.01
# 1           1  PRJNA388263    Metagenomics  Female      21.0  23.50
# 2           2  PRJNA388263    Metagenomics    Male      52.0  25.80
# 3           3   PRJEB11419    Metagenomics  Female      40.0  23.49
# 4           4   PRJEB11419    Metagenomics  Female      30.0  22.60
#
#   Disease MESH ID  Acholeplasma axanthum  Acidaminococcus fermentans  \
# 0         D006262               0.000000                    0.000000
# 1         D006262               0.001028                    0.000000
# 2         D006262               0.001406                    0.000000
# 3         D006262               0.000000                    0.008825
# 4         D006262               0.002878                    0.037419
#
#    Acidaminococcus intestini  ...  Clostridium sphenoides  \
# 0                   0.000000  ...                0.005891
# 1                   0.000000  ...                0.000000
# 2                   0.000000  ...                0.000000
# 3                   0.273562  ...                0.017649
# 4                   7.359970  ...                0.305106
#
#    Clostridium spiroforme  Clostridium stercorarium  Clostridium symbiosum  \
# 0                0.029457                  0.000000               0.000000
# 1                0.002569                  0.412652               0.003083
# 2                0.005624                  0.002812               0.007031
# 3                0.198553                  0.000000               0.158842
# 4                0.135283                  0.000000               0.051811
#
#    Clostridium thermosuccinogenes  Clostridium xylanolyticum  \
# 0                        0.002946                   0.000000
# 1                        0.000000                   0.000000
# 2                        0.000000                   0.000000
# 3                        0.030886                   0.101483
# 4                        0.054689                   0.083473
#
#    Eubacterium brachy  Eubacterium dolichum  Eubacterium sulci  \
# 0            0.000000              0.000000           0.002946
# 1            0.008736              0.014903           0.077597
# 2            0.000000              0.000000           0.005624
# 3            0.000000              0.000000           0.000000
# 4            0.020148              0.000000           0.054689
#
#    Ruminococcus gnavus
# 0             0.100153
# 1             0.004625
# 2             0.016873
# 3             0.000000
# 4             0.011513
#
# [5 rows x 141 columns]
# b
#
#
#
#
# c
# d
#      Unnamed: 0   Project ID Experiment type     Sex  Host age    BMI  \
# 206         206   PRJEB11419    Metagenomics  Female      51.0  22.67
# 207         207  PRJNA379979    Metagenomics    Male      54.0  25.60
# 208         208  PRJNA388263    Metagenomics    Male      52.0  25.80
# 209         209   PRJEB11419    Metagenomics    Male      26.0  26.54
# 210         210   PRJEB11419    Metagenomics  Female      19.0  22.86
#
#     Disease MESH ID  Acholeplasma axanthum  Acidaminococcus fermentans  \
# 206         D006262                    0.0                         0.0
# 207         D006262                    0.0                         0.0
# 208         D006262                    0.0                         0.0
# 209         D006262                    0.0                         0.0
# 210         D006262                    0.0                         0.0
#
#      Acidaminococcus intestini  ...  Clostridium sphenoides  \
# 206                   0.692094  ...                0.010104
# 207                   0.000000  ...                0.000000
# 208                   0.000000  ...                0.000000
# 209                   0.015966  ...                0.005322
# 210                   0.000000  ...                0.000000
#
#      Clostridium spiroforme  Clostridium stercorarium  Clostridium symbiosum  \
# 206                0.383935                  0.000000               0.070725
# 207                0.000000                  0.000000               0.000000
# 208                0.023239                  0.001452               0.015977
# 209                0.564130                  0.000000               0.015966
# 210                0.125413                  0.000000               0.197621
#
#      Clostridium thermosuccinogenes  Clostridium xylanolyticum  \
# 206                             0.0                   0.045466
# 207                             0.0                   0.000000
# 208                             0.0                   0.000000
# 209                             0.0                   0.074508
# 210                             0.0                   0.003800
#
#      Eubacterium brachy  Eubacterium dolichum  Eubacterium sulci  \
# 206            0.000000              0.000000           0.000000
# 207            0.000000              0.000000           0.000000
# 208            0.001452              0.000000           0.013072
# 209            0.000000              0.000000           0.000000
# 210            0.003800              0.030403           0.000000
#
#      Ruminococcus gnavus
# 206             0.015155
# 207             0.000000
# 208             0.015977
# 209             0.021288
# 210             0.543458
#
# [5 rows x 141 columns]

# %%
# 1. Show Missing Values
print("Checking for missing values in development and validation datasets...\n")

# Development data
print(gmDevData.isnull())
missing_dev = gmDevData.isnull().sum()
print("\n\n\n\nInitial missing dev")
print(missing_dev)
print("\n\n\n\n\n")
missing_dev = missing_dev[missing_dev > 0]  # Filter columns with missing values
print("Development Data - Missing Values:\n", missing_dev)

# Validation data
missing_val = gmValData.isnull().sum()
missing_val = missing_val[missing_val > 0]  # Filter columns with missing values
print("\nValidation Data - Missing Values:\n", missing_val)

# If no missing values, notify user and proceed
if missing_dev.empty and missing_val.empty:
    print("\nNo missing values found in either dataset.")
else:
    print("\nMissing values detected. Proceeding with cleaning...")


#print(gmDevData.head())
#print(gmValData.head())
#print("INFO")
#print(gmDevData.info())
#print(gmValData.info())
#print("DESCRIBE")
#print(gmDevData.describe())
#print(gmValData.describe())
print(gmDevData.isnull().sum())
# Remove any rows with missing values
gmDevData_cleaned = gmDevData.dropna()

# Remove any duplicate rows
gmDevData_cleaned = gmDevData_cleaned.drop_duplicates()

# Reset the index
gmDevData_cleaned = gmDevData_cleaned.reset_index(drop=True)


#gmDevData_cleaned.info()
gmDevData_cleaned.head()
# Out:
# Checking for missing values in development and validation datasets...
#
#      Unnamed: 0  Project ID  Experiment type    Sex  Host age    BMI  \
# 0         False       False            False  False     False  False
# 1         False       False            False  False     False  False
# 2         False       False            False  False     False  False
# 3         False       False            False  False     False  False
# 4         False       False            False  False     False  False
# ..          ...         ...              ...    ...       ...    ...
# 484       False       False            False  False     False  False
# 485       False       False            False  False     False  False
# 486       False       False            False  False     False  False
# 487       False       False            False  False     False  False
# 488       False       False            False  False     False  False
#
#      Disease MESH ID  Acholeplasma axanthum  Acidaminococcus fermentans  \
# 0              False                  False                       False
# 1              False                  False                       False
# 2              False                  False                       False
# 3              False                  False                       False
# 4              False                  False                       False
# ..               ...                    ...                         ...
# 484            False                  False                       False
# 485            False                  False                       False
# 486            False                  False                       False
# 487            False                  False                       False
# 488            False                  False                       False
#
#      Acidaminococcus intestini  ...  Clostridium sphenoides  \
# 0                        False  ...                   False
# 1                        False  ...                   False
# 2                        False  ...                   False
# 3                        False  ...                   False
# 4                        False  ...                   False
# ..                         ...  ...                     ...
# 484                      False  ...                   False
# 485                      False  ...                   False
# 486                      False  ...                   False
# 487                      False  ...                   False
# 488                      False  ...                   False
#
#      Clostridium spiroforme  Clostridium stercorarium  Clostridium symbiosum  \
# 0                     False                     False                  False
# 1                     False                     False                  False
# 2                     False                     False                  False
# 3                     False                     False                  False
# 4                     False                     False                  False
# ..                      ...                       ...                    ...
# 484                   False                     False                  False
# 485                   False                     False                  False
# 486                   False                     False                  False
# 487                   False                     False                  False
# 488                   False                     False                  False
#
#      Clostridium thermosuccinogenes  Clostridium xylanolyticum  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                             False                      False
# 4                             False                      False
# ..                              ...                        ...
# 484                           False                      False
# 485                           False                      False
# 486                           False                      False
# 487                           False                      False
# 488                           False                      False
#
#      Eubacterium brachy  Eubacterium dolichum  Eubacterium sulci  \
# 0                 False                 False              False
# 1                 False                 False              False
# 2                 False                 False              False
# 3                 False                 False              False
# 4                 False                 False              False
# ..                  ...                   ...                ...
# 484               False                 False              False
# 485               False                 False              False
# 486               False                 False              False
# 487               False                 False              False
# 488               False                 False              False
#
#      Ruminococcus gnavus
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 484                False
# 485                False
# 486                False
# 487                False
# 488                False
#
# [489 rows x 141 columns]
#
#
#
#
# Initial missing dev
# Unnamed: 0                   0
# Project ID                   0
# Experiment type              0
# Sex                          0
# Host age                     0
#                             ..
# Clostridium xylanolyticum    0
# Eubacterium brachy           0
# Eubacterium dolichum         0
# Eubacterium sulci            0
# Ruminococcus gnavus          0
# Length: 141, dtype: int64
#
#
#
#
#
#
# Development Data - Missing Values:
#  Series([], dtype: int64)
#
# Validation Data - Missing Values:
#  Series([], dtype: int64)
#
# No missing values found in either dataset.
# Unnamed: 0                   0
# Project ID                   0
# Experiment type              0
# Sex                          0
# Host age                     0
#                             ..
# Clostridium xylanolyticum    0
# Eubacterium brachy           0
# Eubacterium dolichum         0
# Eubacterium sulci            0
# Ruminococcus gnavus          0
# Length: 141, dtype: int64
#    Unnamed: 0   Project ID Experiment type     Sex  Host age    BMI  \
# 0           0   PRJEB11419    Metagenomics    Male      53.0  19.01
# 1           1  PRJNA388263    Metagenomics  Female      21.0  23.50
# 2           2  PRJNA388263    Metagenomics    Male      52.0  25.80
# 3           3   PRJEB11419    Metagenomics  Female      40.0  23.49
# 4           4   PRJEB11419    Metagenomics  Female      30.0  22.60
#
#   Disease MESH ID  Acholeplasma axanthum  Acidaminococcus fermentans  \
# 0         D006262               0.000000                    0.000000
# 1         D006262               0.001028                    0.000000
# 2         D006262               0.001406                    0.000000
# 3         D006262               0.000000                    0.008825
# 4         D006262               0.002878                    0.037419
#
#    Acidaminococcus intestini  ...  Clostridium sphenoides  \
# 0                   0.000000  ...                0.005891
# 1                   0.000000  ...                0.000000
# 2                   0.000000  ...                0.000000
# 3                   0.273562  ...                0.017649
# 4                   7.359970  ...                0.305106
#
#    Clostridium spiroforme  Clostridium stercorarium  Clostridium symbiosum  \
# 0                0.029457                  0.000000               0.000000
# 1                0.002569                  0.412652               0.003083
# 2                0.005624                  0.002812               0.007031
# 3                0.198553                  0.000000               0.158842
# 4                0.135283                  0.000000               0.051811
#
#    Clostridium thermosuccinogenes  Clostridium xylanolyticum  \
# 0                        0.002946                   0.000000
# 1                        0.000000                   0.000000
# 2                        0.000000                   0.000000
# 3                        0.030886                   0.101483
# 4                        0.054689                   0.083473
#
#    Eubacterium brachy  Eubacterium dolichum  Eubacterium sulci  \
# 0            0.000000              0.000000           0.002946
# 1            0.008736              0.014903           0.077597
# 2            0.000000              0.000000           0.005624
# 3            0.000000              0.000000           0.000000
# 4            0.020148              0.000000           0.054689
#
#    Ruminococcus gnavus
# 0             0.100153
# 1             0.004625
# 2             0.016873
# 3             0.000000
# 4             0.011513
#
# [5 rows x 141 columns]

# %%
import seaborn as sns
plt.style.use('seaborn-v0_8')
sns.set_palette('viridis')

plt.figure(figsize=(10, 6))
sns.histplot(gmDevData['BMI'], kde=True)
plt.title('Distribution of BMI in Development Data')
plt.xlabel('BMI')
plt.show()

# Correlation heatmap for development data
# Assuming there are numerical features related to gut microbiome
plt.figure(figsize=(12, 10))
corr_matrix = gmDevData.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap of Features in Development Data')
plt.show()
